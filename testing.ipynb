# %% [markdown]
# # Purely for testing!
# ## TEST 2
# ### TEST 3

# %%
from datetime import datetime
import pandas as pd

# %%
test = pd.read_csv('output\Time_24.21.10_IN_MYnewvideos.csv')

# %%
test
# Out:
#         video_id                                              title  \
# 0    CEfYokG1SF8  Bagheera Kannada Official Trailer | Sriimurali...
# 1    d4_Qm9SJIu0  India 'A' vs Pakistan 'A' | Men's T20 Emerging...
# 2    uy-OS4STuWo          HACKER OR WHAT! | JONATHAN IS BACK | BGMI
# 3    q-hpawQV4iE  I Spend Rs10,00,000 in 100 Hours with @trigger...
# 4    mnWhZ3tT3i8  Son Of Satyamurthy 2 - Ram Pothineni Blockbust...
# ..           ...                                                ...
# 139  osTPY9R_ROY  NEW! Taarak Mehta Ka Ooltah Chashmah | Ep 4219...
# 140  Hg0Ligi3yaA  Patharamattu Promo || 19-10-2024 || Episode 43...
# 141  ll2x-QTaaNM  Hyper Aadi, Pradeep, Sekhar Master, Poorna, So...
# 142  A5wq6KE_FiA  ഉണ്ട പായുന്ന ടാങ്കർ 😁  പൈസ പോയോ ??? | Army Tan...
# 143  QZM2w_tckZU               Uppum Mulakum 3 | Flowers | EP # 100
#
#               publishedAt                 channelId           channelTitle  \
# 0    2024-10-21T04:06:00Z  UCarJoVXH0T2pdtcHBu9J8Bw          Hombale Films
# 1    2024-10-19T18:08:17Z  UC7ITT3ooYWDYY_ehIUbt6eg  Asian Cricket Council
# 2    2024-10-20T21:14:59Z  UCNoiWmvkDUL0q-6ECxNFH0Q        JONATHAN GAMING
# 3    2024-10-20T07:31:41Z  UClfos9f7uDdoun8ZyE9jYFg           Fukra Insaan
# 4    2024-10-19T10:30:06Z  UCyoXW-Dse7fURq30EWl_CUA              Goldmines
# ..                    ...                       ...                    ...
# 139  2024-10-18T15:30:16Z  UC6-F5tO8uklgE9Zy8IvbdFw               Sony SAB
# 140  2024-10-19T02:00:51Z  UCp_r6Z-Oh0YTf-ym71z5Nqg                Asianet
# 141  2024-10-19T14:30:22Z  UCrhHQd5lAQZz3xRLaCJmitA          ETV Originals
# 142  2024-10-16T13:32:08Z  UC4rKvhYJIN-2Pe6zGtxtIqw           M4 TECH VLOG
# 143  2024-10-18T14:24:47Z  UCmAPdImtXLGh5E-lTTH4Qmg         Flowers Comedy
#
#        duration definition          category trending_date  \
# 0       PT2M36S         hd     Entertainment      24.21.10
# 1      PT10M41S         hd            Sports      24.21.10
# 2    PT6H17M51S         hd            Gaming      24.21.10
# 3      PT18M10S         hd     Entertainment      24.21.10
# 4     PT2H1M51S         hd  Film & Animation      24.21.10
# ..          ...        ...               ...           ...
# 139    PT10M39S         hd     Entertainment      24.21.10
# 140        PT1M         hd     Entertainment      24.21.10
# 141     PT8M55S         hd     Entertainment      24.21.10
# 142     PT10M3S         hd     Entertainment      24.21.10
# 143    PT23M15S         hd     Entertainment      24.21.10
#
#                                                   tags  view_count   likes  \
# 0    Hombale films|hombale films channel|hombale|ho...     1742854  122595
# 1                                               [none]     8144201  143564
# 2    jonathan|jonathan gaming|esports|BGMI|BattleGr...     2859301  238030
# 3    fukra insaan|triggered insaan|wanderers hub|fu...     2438639  160738
# 4    Goldmines|son of satyamurthy 2 hindi dubbed mo...     2641216   40604
# ..                                                 ...         ...     ...
# 139  Nitish Bhaluni|तारक मेहता|Ooltah Chashmah|sab ...     1961549   28011
# 140  Abhinand|Adarsh|Anagha|Anantha Moorthy|Anirudh...      362963    3809
# 141  dhee 15|dhee|dhee 13|championship battle|etv d...      226687    1675
# 142                                             [none]      294573    9625
# 143  flowers tv|flower tv comedy|flower tv malayala...      676411   18002
#
#      dislikes  comment_count                                  thumbnail_link  \
# 0           0           5415  https://i.ytimg.com/vi/CEfYokG1SF8/default.jpg
# 1           0           4972  https://i.ytimg.com/vi/d4_Qm9SJIu0/default.jpg
# 2           0            756  https://i.ytimg.com/vi/uy-OS4STuWo/default.jpg
# 3           0           5544  https://i.ytimg.com/vi/q-hpawQV4iE/default.jpg
# 4           0           1172  https://i.ytimg.com/vi/mnWhZ3tT3i8/default.jpg
# ..        ...            ...                                             ...
# 139         0            936  https://i.ytimg.com/vi/osTPY9R_ROY/default.jpg
# 140         0             90  https://i.ytimg.com/vi/Hg0Ligi3yaA/default.jpg
# 141         0             42  https://i.ytimg.com/vi/ll2x-QTaaNM/default.jpg
# 142         0            118  https://i.ytimg.com/vi/A5wq6KE_FiA/default.jpg
# 143         0            743  https://i.ytimg.com/vi/QZM2w_tckZU/default.jpg
#
#      hasPaidProductPlacement  comments_disabled  ratings_disabled  \
# 0                      False              False             False
# 1                      False              False             False
# 2                      False              False             False
# 3                      False              False             False
# 4                      False              False             False
# ..                       ...                ...               ...
# 139                    False              False             False
# 140                    False              False             False
# 141                    False              False             False
# 142                    False              False             False
# 143                    False              False             False
#
#                                            description
# 0    ROAR WITH EXCITEMENT!Get ready for the ultimat...
# 1    India 'A' vs Pakistan 'A' | Men's T20 Emerging...
# 2    UC up! Buy 300 UC on BGMI from Google Play sto...
# 3    In today’s video, I’ll be showing you how I sp...
# 4    Surya is overprotective about his father, Nara...
# ..                                                 ...
# 139  Click here to subscribe to SAB: https://www.yo...
# 140  Patharamattu Promo || 19-10-2024 || Episode 43...
# 141  #dheecelebrityspecial #dhee13 #dheejodi  #dhee...
# 142                  Rc Tank : https://amzn.to/3A0MMhu
# 143  'Uppum Mulakum' returns with its third season,...
#
# [144 rows x 19 columns]

# %%
test[test['hasPaidProductPlacement'] == True]
# Out:
#         video_id                                              title  \
# 7    wS8i3j1Zl9I  Every Karwachauth Ever | Ft. Tena Jaiin | The ...
# 23   gYbqSA9B3w0                    Detective Sheela | Take A Break
# 30   Pmk2j70bL6Y                     INDIA'S BEST PHYSICS PROFESSOR
# 95   _oM_x7IraCA  Maharashtra Assembly Election 2024 : लाडक्या ब...
# 101  kUTjCTl1NnM  Oo Meghamala | Episode 4 | Telugu Webseries 20...
#
#               publishedAt                 channelId     channelTitle  \
# 7    2024-10-20T09:33:04Z  UC0QKe0NgW-b0oZvnB5vqiJw  The Paayal Jain
# 23   2024-10-20T04:04:42Z  UCzIciQA6KlhGCZFByEo2wFQ     Take A Break
# 30   2024-10-19T14:30:06Z  UC0rE2qq81of4fojo-KhO5rg      Tanmay Bhat
# 95   2024-10-17T12:30:06Z  UCQ2W9GCHctD59vQpvLKVg3g       Mumbai Tak
# 101  2024-10-17T13:39:43Z  UCgZHFBaPcDGphLGOCHTKIPA       Rowdy Baby
#
#      duration definition         category trending_date  \
# 7    PT20M14S         hd           Comedy      24.21.10
# 23   PT14M45S         hd           Comedy      24.21.10
# 30   PT18M13S         hd           Comedy      24.21.10
# 95    PT33M6S         hd  News & Politics      24.21.10
# 101   PT29M4S         hd    Entertainment      24.21.10
#
#                                                   tags  view_count  likes  \
# 7    the paayal jain new video|the payal jain new v...     1136587  44045
# 23   shorts break|kaamwali bai|kaamwali bai comedy|...      427347  20858
# 30                                              [none]     1576333  87986
# 95   maharashtra election 2024|maharashtra election...      582161   2789
# 101  telugu webseries|telugu shortfilms|webseries t...      290717  13474
#
#      dislikes  comment_count                                  thumbnail_link  \
# 7           0           3051  https://i.ytimg.com/vi/wS8i3j1Zl9I/default.jpg
# 23          0            632  https://i.ytimg.com/vi/gYbqSA9B3w0/default.jpg
# 30          0           3401  https://i.ytimg.com/vi/Pmk2j70bL6Y/default.jpg
# 95          0            952  https://i.ytimg.com/vi/_oM_x7IraCA/default.jpg
# 101         0            211  https://i.ytimg.com/vi/kUTjCTl1NnM/default.jpg
#
#      hasPaidProductPlacement  comments_disabled  ratings_disabled  \
# 7                       True              False             False
# 23                      True              False             False
# 30                      True              False             False
# 95                      True              False             False
# 101                     True              False             False
#
#                                            description
# 7    Hey GuysHappy Karwa Chauth to all of you , we ...
# 23   Download the Duolingo App Now - https://app.ad...
# 30   Download the IMDb App to see the OG Gang’s Wat...
# 95   #MarathiNews  #LatestMarathiNews #MaharashtraP...
# 101  DISCLAIMER : The app or website promoted in th...

# %%
string = "P4DT4H1S"
string = string[2:len(string)]
for char in string:
    if char not in [str(x) for x in [1,2,3,4,5,6,7,8,9]]:
        string = string.replace(char, ":")
print(string)
string = string[0:len(string) - 1]
dur = datetime.strptime(string, '%H:%M:%S').time()
print(dur)
# res = ""
# if len(queue) <= 3:
#     for item in queue:
#         res = res + str(item) + " "
# Out:
# ::4:1:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 8
#       6 print(string)
#       7 string = string[0:len(string) - 1]
# ----> 8 dur = datetime.strptime(string, '%H:%M:%S').time()
#       9 print(dur)
#      10 # res = ""
#      11 # if len(queue) <= 3:
#      12 #     for item in queue:
#      13 #         res = res + str(item) + " "
#
# File d:\anaconda\envs\hust_dl\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File d:\anaconda\envs\hust_dl\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '::4:1' does not match format '%H:%M:%S'
